# %%
import mainsite
import importlib
importlib.reload(mainsite)
from mainsite import get_a_card
# Out:
# 2025-07-28 17:18:58.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
c = get_a_card(debug=True)
# Out:
# 2025-07-28 17:19:03.862 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 17:19:03.866 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 17:19:03.868 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 17:19:03.871 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 17:19:03.873 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 17:19:03.876 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
c

# %%
# read in lapok.csv into pandas dataframe
import pandas as pd

cards = pd.read_csv("Az én kicsi pártom - Kártyák.csv")

# %%
# keep those where "online" is x
cards = cards[cards["online"] == "x"]
# keep columns Kártya leírás HUN, Típus - HUN, Jobbos bonus, Balos bonus
cards = cards[["online", "Kártya leírás HUN", "Típus - HUN", "Jobbos bonus", "Balos Bonus"]]
# convert "Jobbos bonus" and "Balos Bonus" to int
cards["Jobbos bonus"] = cards["Jobbos bonus"].astype(int)
cards["Balos Bonus"] = cards["Balos Bonus"].astype(int)

# %%
from functions import read_in_cards

# %%
t = read_in_cards()

# %%
t
# Out:
#    online                                  Kártya leírás HUN      Típus - HUN  \
# 4       x                                A hús, mint energia          Kampány
# 5       x                        A kábítószerek legalizálása          Kampány
# 6       x                              A kutatás fejlesztése          Kampány
# 7       x                                      Adócsökkentés          Kampány
# 8       x                     Az egyik képviselőd állatkínzó          Esemény
# 9       x                                Budaházy Felmentése          Esemény
# 10      x                           Csökkented a nyugdíjakat          Esemény
# 11      x                    Drogot találnak a képviselődnél          Esemény
# 12      x                  Eladod a nemzeti bankot a fiadnak          Esemény
# 13      x                Eladod a nemzeti bankot a zsidóknak          Esemény
# 14      x            Eladod Rákosrendezőt arab befektetőknek          Esemény
# 15      x                             Élteted Horthy Miklóst          Esemény
# 16      x                                     Élteted Marxot          Esemény
# 17      x                      Elveszed a 13. havi nyugdíjat          Esemény
# 19      x           Háborút indítasz a trianoni területekért          Kampány
# 21      x  Kedvenc oligarchád újabb 30 éves kizárólagos k...          Esemény
# 22      x  Kedvenc spin doctorod londoni lakásába vitt ne...          Esemény
# 23      x                            Kötelező hittan oktatás          Kampány
# 24      x                             Kötelező lovas íjászat          Kampány
# 25      x                           Kötelező templomi esküvő          Kampány
# 26      x                                 Kritizálod az EU-t          Esemèny
# 27      x                       LMBTQ előadások az iskolában          Kampány
# 28      x                           Melegházasság elfogadása          Kampány
# 29      x               Nemzetek betelepítése Magyarországra          Kampány
# 30      x                   Objektív tájékoztatás a médiában          Kampány
# 31      x  Olimpiát rendeznél rengeteg pénzből, Budapest ...          Kampány
# 32      x           Pedofil fotókat találnak a képviselődnél          Esemény
# 33      x                 Privatizálsz valamit a rokonaidnak  Esemény/Kampány
# 34      x                Roma integrációs program bevezetése          Kampány
# 35      x                                        Sokat lopsz          Esemény
# 36      x                         Szabad pálinkafőzés otthon          Kampány
# 37      x                                    Szakszervezetek              NaN
# 38      x                          Szegregált iskola program          Kampány
# 41      x                                  Vasárnapi boltzár          Kampány
# 42      x                              Vegán életmód előnyei          Kampány
#
#     Jobbos bonus  Balos Bonus
# 4              1            2
# 5              3            1
# 6              1            1
# 7              1            1
# 8              2            3
# 9              1            3
# 10             1            1
# 11             2            1
# 12             1            2
# 13             2            1
# 14             3            1
# 15             1            3
# 16             3            1
# 17             1            1
# 19             1            3
# 21             1            1
# 22             1            1
# 23             1            3
# 24             1            3
# 25             1            2
# 26             1            3
# 27             3            1
# 28             2            1
# 29             3            1
# 30             1            1
# 31             3            1
# 32             3            2
# 33             1            1
# 34             2            1
# 35             1            1
# 36             2            1
# 37             2            1
# 38             1            2
# 41             1            1
# 42             2            1
